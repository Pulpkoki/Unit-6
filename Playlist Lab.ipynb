# %%
import config

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
results = sp.search(q="Like a Rolling Stone",limit=1,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Like+a+Rolling+Stone&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#        'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#        'id': '74ASZWbe4lXaubB36ztrGX',
#        'name': 'Bob Dylan',
#        'type': 'artist',
#        'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6YabPKtZAjxwyWbuO9p4ZD'},
#      'href': 'https://api.spotify.com/v1/albums/6YabPKtZAjxwyWbuO9p4ZD',
#      'id': '6YabPKtZAjxwyWbuO9p4ZD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27341720ef0ae31e10d39e43ca2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0241720ef0ae31e10d39e43ca2',
#        'width': 300},
# ...

# %%
Top100_1971 = sp.user_playlist_tracks("spotify", "1Q3xkLA1R06gIrBo3k4U1q")

# %%
Top100_1971['items']
# Out:
# [{'added_at': '2019-10-16T17:39:14Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/numanuma987'},
#    'href': 'https://api.spotify.com/v1/users/numanuma987',
#    'id': 'numanuma987',
#    'type': 'user',
#    'uri': 'spotify:user:numanuma987'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v8jlSmAQfrkTjAlpUfWtu'},
#       'href': 'https://api.spotify.com/v1/artists/5v8jlSmAQfrkTjAlpUfWtu',
#       'id': '5v8jlSmAQfrkTjAlpUfWtu',
#       'name': 'Perry Como',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v8jlSmAQfrkTjAlpUfWtu'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4D8PfDrsA4I4TegMAMjGjk'},
#     'href': 'https://api.spotify.com/v1/albums/4D8PfDrsA4I4TegMAMjGjk',
#     'id': '4D8PfDrsA4I4TegMAMjGjk',
#     'images': [{'height': 640,
# ...

# %%
print(list(Top100_1971.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",Top100_1971["total"]) #  Let's check items:
len(Top100_1971["items"])
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  99
# 99

# %%
Top100_1971['items'][0]
#to fetch the first track's info - but there are no features there
# Out:
# {'added_at': '2019-10-16T17:39:14Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/numanuma987'},
#   'href': 'https://api.spotify.com/v1/users/numanuma987',
#   'id': 'numanuma987',
#   'type': 'user',
#   'uri': 'spotify:user:numanuma987'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v8jlSmAQfrkTjAlpUfWtu'},
#      'href': 'https://api.spotify.com/v1/artists/5v8jlSmAQfrkTjAlpUfWtu',
#      'id': '5v8jlSmAQfrkTjAlpUfWtu',
#      'name': 'Perry Como',
#      'type': 'artist',
#      'uri': 'spotify:artist:5v8jlSmAQfrkTjAlpUfWtu'}],
#    'available_markets': [],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4D8PfDrsA4I4TegMAMjGjk'},
#    'href': 'https://api.spotify.com/v1/albums/4D8PfDrsA4I4TegMAMjGjk',
#    'id': '4D8PfDrsA4I4TegMAMjGjk',
#    'images': [{'height': 640,
# ...

# %%
track = sp.search(q="Like a Rolling Stone") #find title of the first track
track
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Like+a+Rolling+Stone&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74ASZWbe4lXaubB36ztrGX'},
#        'href': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX',
#        'id': '74ASZWbe4lXaubB36ztrGX',
#        'name': 'Bob Dylan',
#        'type': 'artist',
#        'uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
# ...

# %%
sp.audio_features(track["tracks"]["items"][0]["id"])
# Out:
# [{'danceability': 0.482,
#   'energy': 0.721,
#   'key': 0,
#   'loudness': -6.839,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.731,
#   'instrumentalness': 0,
#   'liveness': 0.189,
#   'valence': 0.557,
#   'tempo': 95.263,
#   'type': 'audio_features',
#   'id': '3AhXZa8sUQht0UEdBJgpGc',
#   'uri': 'spotify:track:3AhXZa8sUQht0UEdBJgpGc',
#   'track_href': 'https://api.spotify.com/v1/tracks/3AhXZa8sUQht0UEdBJgpGc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AhXZa8sUQht0UEdBJgpGc',
#   'duration_ms': 369600,
#   'time_signature': 4}]

# %%
Top100_1971["items"][0]["track"]["name"]
# Out:
# "It's Impossible"

# %%
song_list = []
song_features_list = []
lenght = len(playlist["items"])
playlist = sp.user_playlist_tracks("spotify", "59pRUY7wdHjzAyetJtqCnY")
for i in range(lenght):
    song = playlist['items'][i]['track']['name']
    song_list.append(song)
    track = sp.search(q=song)
    pippo = sp.audio_features(track["tracks"]["items"][0]["id"])
    song_features_list.append(pippo)
    print(song,pippo)
print(len(song_list))
# Out:
# Power [{'danceability': 0.542, 'energy': 0.914, 'key': 0, 'loudness': -4.747, 'mode': 0, 'speechiness': 0.113, 'acousticness': 0.0161, 'instrumentalness': 0, 'liveness': 0.744, 'valence': 0.576, 'tempo': 153.993, 'type': 'audio_features', 'id': '2gZUPNdnz5Y45eiGxpHGSc', 'uri': 'spotify:track:2gZUPNdnz5Y45eiGxpHGSc', 'track_href': 'https://api.spotify.com/v1/tracks/2gZUPNdnz5Y45eiGxpHGSc', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2gZUPNdnz5Y45eiGxpHGSc', 'duration_ms': 292093, 'time_signature': 4}]
# ...

# %%
song_features_list[1]
# Out:
# [{'danceability': 0.862,
#   'energy': 0.624,
#   'key': 3,
#   'loudness': -11.63,
#   'mode': 1,
#   'speechiness': 0.0565,
#   'acousticness': 0.0192,
#   'instrumentalness': 0.000153,
#   'liveness': 0.0465,
#   'valence': 0.882,
#   'tempo': 124.896,
#   'type': 'audio_features',
#   'id': '3yDhZq8f17SmumVmEyCaRN',
#   'uri': 'spotify:track:3yDhZq8f17SmumVmEyCaRN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yDhZq8f17SmumVmEyCaRN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yDhZq8f17SmumVmEyCaRN',
#   'duration_ms': 254240,
#   'time_signature': 4}]

# %%
print(len(playlist["items"]))
# Out:
# 65

# %%
df = pd.DataFrame(columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
       'time_signature'])
df
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []

# %%
df = pd.DataFrame()
for i in range(0,lenght):
    df = df.append(pd.DataFrame(song_features_list[i]))
    print(df)
# Out:
# /var/folders/hx/2m21cb213ll3tclrd0zbbg8c0000gn/T/ipykernel_85032/28494568.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(song_features_list[i]))
# /var/folders/hx/2m21cb213ll3tclrd0zbbg8c0000gn/T/ipykernel_85032/28494568.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(song_features_list[i]))
# /var/folders/hx/2m21cb213ll3tclrd0zbbg8c0000gn/T/ipykernel_85032/28494568.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(song_features_list[i]))
# ...

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.542   0.914    0    -4.747     0       0.1130        0.0161
# 1          0.862   0.624    3   -11.630     1       0.0565        0.0192
# 2          0.847   0.690    1    -7.877     0       0.0493        0.0127
# 3          0.665   0.738    0    -5.931     0       0.0379        0.0124
# 4          0.848   0.821    2    -5.408     0       0.0527        0.0169
# ..           ...     ...  ...       ...   ...          ...           ...
# 60         0.668   0.726    9    -7.512     1       0.0468        0.0387
# 61         0.700   0.764    9    -4.836     0       0.0314        0.0247
# 62         0.763   0.665   11    -9.063     0       0.0807        0.1220
# 63         0.734   0.814    9    -5.493     1       0.2790        0.0124
# 64         0.618   0.938    9    -3.442     1       0.0456        0.0179
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
df=pd.DataFrame(song_features_list[0])
df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.542   0.914    0    -4.747     0        0.113        0.0161
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0                 0     0.744    0.576  153.993  audio_features
#
#                        id                                   uri  \
# 0  2gZUPNdnz5Y45eiGxpHGSc  spotify:track:2gZUPNdnz5Y45eiGxpHGSc
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2gZUPNdnz5Y4...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2gZU...       292093
#
#    time_signature
# 0               4

# %%
df.columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
       'time_signature']
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
df.append(df2)

# %%
def get_song_features(playlist):
    for i in range(0,100):
        song = playlist['items'][i]['track']['name']
        song_list.append(song)
        track = sp.search(q=song)
        sp.audio_features(track["tracks"]["items"][0]["id"] )
